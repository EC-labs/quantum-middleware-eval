# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./metrics.csv')
df.head()
# Out:
#    Num_Qubits  Layers  Iterations  \
# 0           2       1          10
# 1           2       1          50
# 2           2       1         100
# 3           2       2          10
# 4           2       2          50
#
#                                        Optimal_Point  Optimal_Value  Mean_CPU  \
# 0             [6.706014425713531, 5.015816070101175]      -0.473698     31.62
# 1             [5.1048520379891045, 4.72667588322309]      -0.499949     39.36
# 2            [4.319540193655231, 1.5701225928922478]      -0.500000     43.00
# 3  [1.421818419399459, 6.96766803322794, 4.167661...      -0.338856     34.76
# 4  [6.132033838720083, 3.6841642917340125, 4.5373...      -0.499730     36.72
#
#    Mean_Memory  Elapsed_Time
# 0        80.82     30.765669
# 1        81.18     24.547975
# 2        81.02     25.432519
# 3        80.20     33.508807
# 4        80.12     35.758451

# %%
df.columns
# Out:
# Index(['Num_Qubits', 'Layers', 'Iterations', 'Optimal_Point', 'Optimal_Value',
#        'Mean_CPU', 'Mean_Memory', 'Elapsed_Time'],
#       dtype='object')

# %%
# Plotting
fig, axs = plt.subplots(1, 3, figsize=(30, 8))

# Time for qubits
axs[0].plot(df.groupby('Num_Qubits')['Elapsed_Time'].mean(), marker='o')
axs[0].set_title('Average Time for Qubits')
axs[0].set_xlabel('Qubits')
axs[0].set_ylabel('Time')
axs[0].grid(True)

# CPU for qubits
axs[1].plot(df.groupby('Num_Qubits')['Mean_CPU'].mean(), marker='o')
axs[1].set_title('Average CPU for Qubits')
axs[1].set_xlabel('Qubits')
axs[1].set_ylabel('CPU')
axs[1].grid(True)

# Memory for qubits
axs[2].plot(df.groupby('Num_Qubits')['Mean_Memory'].mean(), marker='o')
axs[2].set_title('Average Memory for Qubits')
axs[2].set_xlabel('Qubits')
axs[2].set_ylabel('Memory')
axs[2].grid(True)

plt.suptitle('Effect of Qubits in Workflow', fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Plotting
fig, axs = plt.subplots(1, 3, figsize=(30, 8))

# Time for qubits
axs[0].plot(df.groupby('Iterations')['Elapsed_Time'].mean(), marker='o')
axs[0].set_title('Average Time for Iterations')
axs[0].set_xlabel('Iterations')
axs[0].set_ylabel('Time')
axs[0].grid(True)

# CPU for qubits
axs[1].plot(df.groupby('Iterations')['Mean_CPU'].mean(), marker='o')
axs[1].set_title('Average CPU for Iterations')
axs[1].set_xlabel('Iterations')
axs[1].set_ylabel('CPU')
axs[1].grid(True)

# Memory for qubits
axs[2].plot(df.groupby('Iterations')['Mean_Memory'].mean(), marker='o')
axs[2].set_title('Average Memory for Iterations')
axs[2].set_xlabel('Iterations')
axs[2].set_ylabel('Memory')
axs[2].grid(True)

plt.suptitle('Effect of Iterations in Workflow', fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Plotting
fig, axs = plt.subplots(1, 3, figsize=(30, 8))

# Time for qubits
axs[0].plot(df.groupby('Layers')['Elapsed_Time'].mean(), marker='o')
axs[0].set_title('Average Time for Layers')
axs[0].set_xlabel('Layers')
axs[0].set_ylabel('Time')
axs[0].grid(True)

# CPU for qubits
axs[1].plot(df.groupby('Layers')['Mean_CPU'].mean(), marker='o')
axs[1].set_title('Average CPU for Layers')
axs[1].set_xlabel('Layers')
axs[1].set_ylabel('CPU')
axs[1].grid(True)

# Memory for qubits
axs[2].plot(df.groupby('Layers')['Mean_Memory'].mean(), marker='o')
axs[2].set_title('Average Memory for Layers')
axs[2].set_xlabel('Layers')
axs[2].set_ylabel('Memory')
axs[2].grid(True)

plt.suptitle('Effect of Layers in Workflow', fontsize=16)

plt.tight_layout()
plt.show()
