# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./metrics.csv')
df.head()
# Out:
#              id  iterations  layers  qubits  batch_size      time    cpu  \
# 0  05aefb708e62          10       1       2          16  7.577369  22.35
# 1  0d4d94a54d29          10       1       2          32  8.426041  22.45
# 2  22723f4b4d15          10       1       4          16  7.492163  21.15
# 3  35fd30043946          10       1       4          32  8.384829  25.70
# 4  4be4998d9ad3          10       1       6          16  7.626358  23.80
#
#    memory
# 0   60.70
# 1   61.15
# 2   61.10
# 3   61.00
# 4   61.15

# %%
df.columns
# Out:
# Index(['id', 'iterations', 'layers', 'qubits', 'batch_size', 'time', 'cpu',
#        'memory'],
#       dtype='object')

# %%
# Plotting
fig, axs = plt.subplots(1, 3, figsize=(30, 8))

# Time for qubits
axs[0].plot(df.groupby('qubits')['time'].mean(), marker='o')
axs[0].set_title('Average Time for Qubits')
axs[0].set_xlabel('Qubits')
axs[0].set_ylabel('Time')
axs[0].grid(True)

# CPU for qubits
axs[1].plot(df.groupby('qubits')['cpu'].mean(), marker='o')
axs[1].set_title('Average CPU for Qubits')
axs[1].set_xlabel('Qubits')
axs[1].set_ylabel('CPU')
axs[1].grid(True)

# Memory for qubits
axs[2].plot(df.groupby('qubits')['memory'].mean(), marker='o')
axs[2].set_title('Average Memory for Qubits')
axs[2].set_xlabel('Qubits')
axs[2].set_ylabel('Memory')
axs[2].grid(True)

plt.suptitle('Effect of Qubits in Workflow', fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Plotting
fig, axs = plt.subplots(1, 3, figsize=(30, 8))

# Time for qubits
axs[0].plot(df.groupby('iterations')['time'].mean(), marker='o')
axs[0].set_title('Average Time for Iterations')
axs[0].set_xlabel('Iterations')
axs[0].set_ylabel('Time')
axs[0].grid(True)

# CPU for qubits
axs[1].plot(df.groupby('iterations')['cpu'].mean(), marker='o')
axs[1].set_title('Average CPU for Iterations')
axs[1].set_xlabel('Iterations')
axs[1].set_ylabel('CPU')
axs[1].grid(True)

# Memory for qubits
axs[2].plot(df.groupby('iterations')['memory'].mean(), marker='o')
axs[2].set_title('Average Memory for Iterations')
axs[2].set_xlabel('Iterations')
axs[2].set_ylabel('Memory')
axs[2].grid(True)

plt.suptitle('Effect of Iterations in Workflow', fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Plotting
fig, axs = plt.subplots(1, 3, figsize=(30, 8))

# Time for qubits
axs[0].plot(df.groupby('layers')['time'].mean(), marker='o')
axs[0].set_title('Average Time for Layers')
axs[0].set_xlabel('Layers')
axs[0].set_ylabel('Time')
axs[0].grid(True)

# CPU for qubits
axs[1].plot(df.groupby('layers')['cpu'].mean(), marker='o')
axs[1].set_title('Average CPU for Layers')
axs[1].set_xlabel('Layers')
axs[1].set_ylabel('CPU')
axs[1].grid(True)

# Memory for qubits
axs[2].plot(df.groupby('layers')['memory'].mean(), marker='o')
axs[2].set_title('Average Memory for Layers')
axs[2].set_xlabel('Layers')
axs[2].set_ylabel('Memory')
axs[2].grid(True)

plt.suptitle('Effect of Layers in Workflow', fontsize=16)

plt.tight_layout()
plt.show()
